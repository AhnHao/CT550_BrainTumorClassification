# %% [markdown]
# # *Brain Tumor Classification Project*

# %% [markdown]
# ## 1. Import Library

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from skimage.transform import resize
# Out:
# 2025-10-13 05:05:32.938366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760331933.171332      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760331933.232170      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## 2. Data Loading

# %%
# Data Labels
labels = ['glioma', 'meningioma', 'notumor', 'pituitary']
train_dir = '/kaggle/input/brain-tumor-mri-dataset/Training/'
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Testing/'

X_train = [] #Training Dataset
Y_train = [] #Training Labels

image_size=224

for label in labels:
    path = os.path.join(train_dir, label)
    class_num = labels.index(label)
    for img in os.listdir(path):
        img_array = plt.imread(os.path.join(path, img))
        img_resized = resize(img_array, (image_size, image_size, 3))
        X_train.append(img_resized)
        Y_train.append(class_num)

for label in labels:
    path = os.path.join(test_dir, label)
    class_num = labels.index(label)
    for img in os.listdir(path):
        img_array = plt.imread(os.path.join(path, img))
        img_resized = resize(img_array, (image_size, image_size, 3))
        X_train.append(img_resized)
        Y_train.append(class_num)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train.shape
# Out:
# (7023, 224, 224, 3)

# %% [markdown]
# ## 3. Shuffle & split data (80%-10%-10%)

# %%
from sklearn.model_selection import train_test_split

# Bước 1: shuffle & chia Train+Val (90%) và Test (10%)
X_train, X_test, Y_train, Y_test = train_test_split(
    X_train, Y_train,
    test_size=0.1,
    stratify=Y_train,
    random_state=42, 
    shuffle=True
)

print("Train & Val:", X_train.shape, Y_train.shape)
print("Test:", X_test.shape, Y_test.shape)
# Out:
# Train & Val: (6320, 224, 224, 3) (6320,)
# Test: (703, 224, 224, 3) (703,)

# %%
# Bước 2: chia Train (80%) và Validation (10%)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train, Y_train,
    test_size=0.1111,   # ≈10% tổng dataset
    stratify=Y_train,
    random_state=42,
    shuffle=True
)

# Kiểm tra kích thước
print("Train:", X_train.shape, Y_train.shape)
print("Validation:", X_val.shape, Y_val.shape)
print("Test:", X_test.shape, Y_test.shape)
# Out:
# Train: (5617, 224, 224, 3) (5617,)
# Validation: (703, 224, 224, 3) (703,)
# Test: (703, 224, 224, 3) (703,)

# %%
# Kiểm tra dtype
print("Train:", X_train.dtype, Y_train.dtype)
print("Validation:", X_val.dtype, Y_val.dtype)
print("Test:", X_test.dtype, Y_test.dtype)
# Out:
# Train: float64 int64
# Validation: float64 int64
# Test: float64 int64

# %% [markdown]
# ## 4. Data preprocessing

# %% [markdown]
# ### 4.1 Data standardization

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')

# Y_train_cat = to_categorical(Y_train, num_classes=4)
# Y_val_cat = to_categorical(Y_val, num_classes=4)
# Y_test_cat = to_categorical(Y_test, num_classes=4)

# %%
print("Min pixel:", X_train.min())
print("Max pixel:", X_train.max())
# Out:
# Min pixel: 0.0
# Max pixel: 1.0

# %%
num_samples = 4  # số ảnh mỗi lớp
plt.figure(figsize=(15, 15))

for class_idx, label in enumerate(labels):
    # Lấy index ảnh thuộc lớp này
    idxs = np.where(Y_train == class_idx)[0]
    # Chọn ngẫu nhiên
    sample_idxs = np.random.choice(idxs, num_samples, replace=False)

    for i, idx in enumerate(sample_idxs):
        plt.subplot(len(labels), num_samples, class_idx * num_samples + i + 1)
        plt.imshow(X_train[idx])
        plt.axis("off")
        plt.title(label, fontsize=16, pad=5)

plt.tight_layout(h_pad=2.0)
plt.suptitle("Ảnh ngẫu nhiên từ mỗi lớp", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %% [markdown]
# ### 4.2 Data augmentation with generator

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0),
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=None,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0)
)
test_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0)
)

BATCH_SIZE = 32

train_generator = train_datagen.flow(
    X_train, Y_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_generator = val_datagen.flow(
    X_val, Y_val,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_generator = test_datagen.flow(
    X_test, Y_test,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %% [markdown]
# ### 4.4 Show Generator

# %%
X_batch, Y_batch = next(train_generator)
print("Image shape:", X_batch.shape)
print("Min pixel:", X_batch.min())
print("Max pixel:", X_batch.max())
# Out:
# Image shape: (32, 224, 224, 3)
# Min pixel: -123.68
# Max pixel: 151.061

# %%
num_samples = 4
batch_x, batch_y = next(train_generator)

# Nếu Y là one-hot, chuyển lại thành chỉ số lớp
if batch_y.ndim > 1:
    batch_y = np.argmax(batch_y, axis=1)

# Lấy danh sách các nhãn (label) — ví dụ: ['glioma', 'meningioma', 'notumor', 'pituitary']
labels = ['glioma', 'meningioma', 'notumor', 'pituitary']

plt.figure(figsize=(14, 10))
for class_idx, label in enumerate(labels):
    # Tìm ảnh thuộc lớp này
    idxs = np.where(batch_y == class_idx)[0]
    # Chọn ngẫu nhiên tối đa num_samples ảnh
    sample_idxs = np.random.choice(idxs, min(num_samples, len(idxs)), replace=False)

    for i, idx in enumerate(sample_idxs):
        plt.subplot(len(labels), num_samples, class_idx * num_samples + i + 1)
        plt.imshow(np.clip(batch_x[idx], 0, 1))  # đảm bảo hiển thị đúng
        plt.axis("off")
        plt.title(label, fontsize=12, pad=4)

plt.tight_layout(h_pad=2.0)
plt.suptitle("Ảnh sau khi áp dụng ImageDataGenerator", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %% [markdown]
# ## 5. Train Data with Resnet50

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision, Recall

# %%
# -------------------------
# class weights (nếu cần)
# -------------------------
y_train = Y_train 
classes = np.unique(y_train)
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = {int(k): float(v) for k, v in zip(classes, class_weights)}
print("class_weights:", class_weights)

# -------------------------
# Build model (base + head)
# -------------------------
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 4

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

# build head with L2 + dropout
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(1e-3))(x)
x = Dropout(0.4)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

# -------------------------
# callbacks
# -------------------------
callbacks = [
    ModelCheckpoint('resnet50.h5', monitor='val_loss', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

# freeze backbone
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',  
              metrics=['accuracy'])

# Fit 
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    callbacks=callbacks,
    class_weight=class_weights,  
    verbose=1
)
# Out:
# class_weights: {0: 1.0826908249807248, 1: 1.06787072243346, 2: 0.87765625, 3: 0.9994661921708186}
# I0000 00:00:1760332138.283462      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1760332138.284130      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760332152.078604      64 service.cc:148] XLA service 0x7dc4a4002b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760332152.079589      64 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760332152.079619      64 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760332153.565396      64 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/176 ━━━━━━━━━━━━━━━━━━━━ 13s 78ms/step - accuracy: 0.2500 - loss: 2.9621
# I0000 00:00:1760332159.019154      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4157 - loss: 2.1448
# Epoch 1: val_loss improved from inf to 0.96989, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 84s 384ms/step - accuracy: 0.4164 - loss: 2.1424 - val_accuracy: 0.8179 - val_loss: 0.9699 - learning_rate: 1.0000e-04
# Epoch 2/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.6857 - loss: 1.2438
# Epoch 2: val_loss improved from 0.96989 to 0.89566, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 314ms/step - accuracy: 0.6857 - loss: 1.2436 - val_accuracy: 0.8336 - val_loss: 0.8957 - learning_rate: 1.0000e-04
# Epoch 3/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7505 - loss: 1.0858
# Epoch 3: val_loss improved from 0.89566 to 0.83353, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 316ms/step - accuracy: 0.7506 - loss: 1.0857 - val_accuracy: 0.8563 - val_loss: 0.8335 - learning_rate: 1.0000e-04
# Epoch 4/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7657 - loss: 1.0331
# Epoch 4: val_loss improved from 0.83353 to 0.79778, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 316ms/step - accuracy: 0.7657 - loss: 1.0330 - val_accuracy: 0.8706 - val_loss: 0.7978 - learning_rate: 1.0000e-04
# Epoch 5/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7799 - loss: 0.9736
# Epoch 5: val_loss improved from 0.79778 to 0.78002, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 319ms/step - accuracy: 0.7799 - loss: 0.9735 - val_accuracy: 0.8691 - val_loss: 0.7800 - learning_rate: 1.0000e-04
# Epoch 6/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.7988 - loss: 0.9364
# Epoch 6: val_loss did not improve from 0.78002
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 315ms/step - accuracy: 0.7988 - loss: 0.9364 - val_accuracy: 0.8563 - val_loss: 0.7833 - learning_rate: 1.0000e-04
# Epoch 7/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8006 - loss: 0.9168
# Epoch 7: val_loss improved from 0.78002 to 0.74284, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 314ms/step - accuracy: 0.8007 - loss: 0.9167 - val_accuracy: 0.8734 - val_loss: 0.7428 - learning_rate: 1.0000e-04
# Epoch 8/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8125 - loss: 0.8850
# Epoch 8: val_loss improved from 0.74284 to 0.73405, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 314ms/step - accuracy: 0.8125 - loss: 0.8848 - val_accuracy: 0.8663 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 9/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8210 - loss: 0.8621
# Epoch 9: val_loss improved from 0.73405 to 0.71861, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 318ms/step - accuracy: 0.8210 - loss: 0.8620 - val_accuracy: 0.8620 - val_loss: 0.7186 - learning_rate: 1.0000e-04
# Epoch 10/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8298 - loss: 0.8422
# Epoch 10: val_loss improved from 0.71861 to 0.70266, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 316ms/step - accuracy: 0.8298 - loss: 0.8422 - val_accuracy: 0.8834 - val_loss: 0.7027 - learning_rate: 1.0000e-04
# Epoch 11/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8438 - loss: 0.7917
# Epoch 11: val_loss improved from 0.70266 to 0.68494, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 316ms/step - accuracy: 0.8438 - loss: 0.7918 - val_accuracy: 0.8834 - val_loss: 0.6849 - learning_rate: 1.0000e-04
# Epoch 12/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8490 - loss: 0.7714
# Epoch 12: val_loss improved from 0.68494 to 0.66102, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 317ms/step - accuracy: 0.8490 - loss: 0.7714 - val_accuracy: 0.8777 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 13/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8408 - loss: 0.7842
# Epoch 13: val_loss improved from 0.66102 to 0.64451, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 317ms/step - accuracy: 0.8409 - loss: 0.7841 - val_accuracy: 0.8862 - val_loss: 0.6445 - learning_rate: 1.0000e-04
# Epoch 14/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8440 - loss: 0.7595
# Epoch 14: val_loss improved from 0.64451 to 0.64401, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 317ms/step - accuracy: 0.8441 - loss: 0.7594 - val_accuracy: 0.8862 - val_loss: 0.6440 - learning_rate: 1.0000e-04
# Epoch 15/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8503 - loss: 0.7283
# Epoch 15: val_loss improved from 0.64401 to 0.64110, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 314ms/step - accuracy: 0.8503 - loss: 0.7283 - val_accuracy: 0.8805 - val_loss: 0.6411 - learning_rate: 1.0000e-04
# Epoch 16/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8505 - loss: 0.7315
# Epoch 16: val_loss improved from 0.64110 to 0.62788, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 318ms/step - accuracy: 0.8505 - loss: 0.7314 - val_accuracy: 0.8876 - val_loss: 0.6279 - learning_rate: 1.0000e-04
# Epoch 17/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8589 - loss: 0.6900
# Epoch 17: val_loss improved from 0.62788 to 0.62203, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 56s 317ms/step - accuracy: 0.8589 - loss: 0.6901 - val_accuracy: 0.8791 - val_loss: 0.6220 - learning_rate: 1.0000e-04
# Epoch 18/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8585 - loss: 0.7024
# Epoch 18: val_loss improved from 0.62203 to 0.61303, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 314ms/step - accuracy: 0.8585 - loss: 0.7024 - val_accuracy: 0.8805 - val_loss: 0.6130 - learning_rate: 1.0000e-04
# Epoch 19/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8481 - loss: 0.7082
# Epoch 19: val_loss improved from 0.61303 to 0.58551, saving model to resnet50.h5
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 315ms/step - accuracy: 0.8481 - loss: 0.7080 - val_accuracy: 0.8933 - val_loss: 0.5855 - learning_rate: 1.0000e-04
# Epoch 20/20
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8757 - loss: 0.6564
# Epoch 20: val_loss did not improve from 0.58551
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 55s 313ms/step - accuracy: 0.8756 - loss: 0.6565 - val_accuracy: 0.8919 - val_loss: 0.5903 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ## 6. Evaluation & Report

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
epochs = len(history.history['accuracy'])
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.xticks(np.arange(2, epochs+1, 2))

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks(np.arange(2, epochs+1, 2))

plt.show()

# %%
loss, acc = model.evaluate(test_generator, verbose=1)
print(f"\n Test Accuracy (from model.evaluate): {acc*100:.2f}%\n")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9024 - loss: 0.5486
#
#  Test Accuracy (from model.evaluate): 90.90%

# %%
# Dự đoán trên test 
model.load_weights('resnet50.h5')
y_prob = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_prob, axis=1)

# lấy true labels 
y_true = Y_test

acc = accuracy_score(y_true, y_pred)
print(f"\n Test Accuracy: {acc*100:.2f}%\n")

print(classification_report(y_true, y_pred, target_names=labels))
cm = confusion_matrix(y_true, y_pred)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step
#
#  Test Accuracy: 90.90%
#
#               precision    recall  f1-score   support
#
#       glioma       0.87      0.94      0.91       162
#   meningioma       0.86      0.75      0.80       165
#      notumor       0.97      0.95      0.96       200
#    pituitary       0.91      0.97      0.94       176
#
#     accuracy                           0.91       703
#    macro avg       0.90      0.91      0.90       703
# weighted avg       0.91      0.91      0.91       703

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.show()
