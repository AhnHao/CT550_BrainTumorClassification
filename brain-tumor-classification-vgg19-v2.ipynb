# %% [markdown]
# # *Brain Tumor Classification Project - VGG19*

# %% [markdown]
# ## 1. Import Library

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from skimage.transform import resize
# Out:
# 2025-10-22 11:04:02.389672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761131042.812283      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761131042.926481      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## 2. Data Loading

# %%
# Data Labels
labels = ['glioma', 'meningioma', 'notumor', 'pituitary']
train_dir = '/kaggle/input/brain-tumor-mri-dataset/Training/'
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Testing/'

X_train = [] #Training Dataset
Y_train = [] #Training Labels

image_size=224

for label in labels:
    path = os.path.join(train_dir, label)
    class_num = labels.index(label)
    for img in os.listdir(path):
        img_array = plt.imread(os.path.join(path, img))
        img_resized = resize(img_array, (image_size, image_size, 3))
        X_train.append(img_resized)
        Y_train.append(class_num)

for label in labels:
    path = os.path.join(test_dir, label)
    class_num = labels.index(label)
    for img in os.listdir(path):
        img_array = plt.imread(os.path.join(path, img))
        img_resized = resize(img_array, (image_size, image_size, 3))
        X_train.append(img_resized)
        Y_train.append(class_num)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train.shape
# Out:
# (7023, 224, 224, 3)

# %% [markdown]
# ## 3. Shuffle & split data (70%-10%-20%)

# %%
from sklearn.model_selection import train_test_split

# Bước 1: shuffle & chia Train+Val (80%) và Test (20%)
X_train, X_test, Y_train, Y_test = train_test_split(
    X_train, Y_train,
    test_size=0.2,
    stratify=Y_train,
    random_state=42, 
    shuffle=True
)

print("Train & Val:", X_train.shape, Y_train.shape)
print("Test:", X_test.shape, Y_test.shape)
# Out:
# Train & Val: (5618, 224, 224, 3) (5618,)
# Test: (1405, 224, 224, 3) (1405,)

# %%
# Bước 2: chia Train (70%) và Validation (10%)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train, Y_train,
    test_size=0.125,   
    stratify=Y_train,
    random_state=42,
    shuffle=True
)

# Kiểm tra kích thước
print("Train:", X_train.shape, Y_train.shape)
print("Validation:", X_val.shape, Y_val.shape)
print("Test:", X_test.shape, Y_test.shape)
# Out:
# Train: (4915, 224, 224, 3) (4915,)
# Validation: (703, 224, 224, 3) (703,)
# Test: (1405, 224, 224, 3) (1405,)

# %%
# Kiểm tra dtype
print("Train:", X_train.dtype, Y_train.dtype)
print("Validation:", X_val.dtype, Y_val.dtype)
print("Test:", X_test.dtype, Y_test.dtype)
# Out:
# Train: float64 int64
# Validation: float64 int64
# Test: float64 int64

# %% [markdown]
# ## 4. Data preprocessing

# %% [markdown]
# ### 4.1 Data standardization

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.vgg19 import preprocess_input

# %%
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')

# %%
print("Min pixel:", X_train.min())
print("Max pixel:", X_train.max())
# Out:
# Min pixel: 0.0
# Max pixel: 1.0

# %%
num_samples = 4  # số ảnh mỗi lớp
plt.figure(figsize=(15, 15))

for class_idx, label in enumerate(labels):
    # Lấy index ảnh thuộc lớp này
    idxs = np.where(Y_train == class_idx)[0]
    # Chọn ngẫu nhiên
    sample_idxs = np.random.choice(idxs, num_samples, replace=False)

    for i, idx in enumerate(sample_idxs):
        plt.subplot(len(labels), num_samples, class_idx * num_samples + i + 1)
        plt.imshow(X_train[idx])
        plt.axis("off")
        plt.title(label, fontsize=16, pad=5)

plt.tight_layout(h_pad=2.0)
plt.suptitle("Ảnh ngẫu nhiên từ mỗi lớp", fontsize=16, fontweight="bold", y=1.02)
plt.show()

# %% [markdown]
# ### 4.2 Data augmentation with generator

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0),
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=None,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0)
)
test_datagen = ImageDataGenerator(
    preprocessing_function=lambda x: preprocess_input(x * 255.0)
)

BATCH_SIZE = 32

train_generator = train_datagen.flow(
    X_train, Y_train,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_generator = val_datagen.flow(
    X_val, Y_val,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_generator = test_datagen.flow(
    X_test, Y_test,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %% [markdown]
# ### 4.4 Show Generator

# %%
X_batch, Y_batch = next(train_generator)
print("Image shape:", X_batch.shape)
print("Min pixel:", X_batch.min())
print("Max pixel:", X_batch.max())
# Out:
# Image shape: (32, 224, 224, 3)
# Min pixel: -123.68
# Max pixel: 151.061

# %% [markdown]
# ## 5. Train Data with VGG19

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision, Recall

# %%
# -------------------------
# class weights 
# -------------------------
y_train = Y_train 
classes = np.unique(y_train)
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = {int(k): float(v) for k, v in zip(classes, class_weights)}
print("class_weights:", class_weights)

# -------------------------
# Build model (base + head)
# -------------------------
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 4

base_model = VGG19(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

# build head with L2 + dropout
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(1e-3))(x)
x = Dropout(0.4)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)
model.summary()

# -------------------------
# callbacks
# -------------------------
callbacks = [
    ModelCheckpoint('vgg19v2.h5', monitor='val_loss', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

# freeze backbone
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',  
              metrics=['accuracy'])

# Fit 
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks,
    class_weight=class_weights,  
    verbose=1
)
# Out:
# class_weights: {0: 1.0825991189427313, 1: 1.0675499565595135, 2: 0.8776785714285714, 3: 0.9997965825874695}
# I0000 00:00:1761131292.911959      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761131292.912660      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,156,740 (76.89 MB)
#  Trainable params: 20,156,740 (76.89 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761131299.096770      64 service.cc:148] XLA service 0x7db7c4010240 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761131299.098463      64 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761131299.098484      64 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761131299.635828      64 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/154 ━━━━━━━━━━━━━━━━━━━━ 39:09 15s/step - accuracy: 0.3125 - loss: 3.9480
# I0000 00:00:1761131311.671809      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.4941 - loss: 2.8250
# Epoch 1: val_loss improved from inf to 0.87661, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 88s 472ms/step - accuracy: 0.4946 - loss: 2.8196 - val_accuracy: 0.7852 - val_loss: 0.8766 - learning_rate: 0.0010
# Epoch 2/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6740 - loss: 1.1894
# Epoch 2: val_loss improved from 0.87661 to 0.83666, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 356ms/step - accuracy: 0.6740 - loss: 1.1891 - val_accuracy: 0.8122 - val_loss: 0.8367 - learning_rate: 0.0010
# Epoch 3/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7216 - loss: 1.0378
# Epoch 3: val_loss improved from 0.83666 to 0.76654, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 357ms/step - accuracy: 0.7216 - loss: 1.0376 - val_accuracy: 0.8350 - val_loss: 0.7665 - learning_rate: 0.0010
# Epoch 4/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7355 - loss: 0.9731
# Epoch 4: val_loss improved from 0.76654 to 0.72204, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 355ms/step - accuracy: 0.7355 - loss: 0.9729 - val_accuracy: 0.8321 - val_loss: 0.7220 - learning_rate: 0.0010
# Epoch 5/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7510 - loss: 0.9199
# Epoch 5: val_loss improved from 0.72204 to 0.71226, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 358ms/step - accuracy: 0.7510 - loss: 0.9198 - val_accuracy: 0.8435 - val_loss: 0.7123 - learning_rate: 0.0010
# Epoch 6/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7627 - loss: 0.8627
# Epoch 6: val_loss improved from 0.71226 to 0.69211, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 358ms/step - accuracy: 0.7627 - loss: 0.8627 - val_accuracy: 0.8250 - val_loss: 0.6921 - learning_rate: 0.0010
# Epoch 7/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7699 - loss: 0.8343
# Epoch 7: val_loss improved from 0.69211 to 0.68530, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 354ms/step - accuracy: 0.7698 - loss: 0.8344 - val_accuracy: 0.8321 - val_loss: 0.6853 - learning_rate: 0.0010
# Epoch 8/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7752 - loss: 0.8172
# Epoch 8: val_loss improved from 0.68530 to 0.57223, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 356ms/step - accuracy: 0.7753 - loss: 0.8172 - val_accuracy: 0.8905 - val_loss: 0.5722 - learning_rate: 0.0010
# Epoch 9/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7813 - loss: 0.8017
# Epoch 9: val_loss did not improve from 0.57223
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 355ms/step - accuracy: 0.7812 - loss: 0.8017 - val_accuracy: 0.8791 - val_loss: 0.5932 - learning_rate: 0.0010
# Epoch 10/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7773 - loss: 0.7961
# Epoch 10: val_loss improved from 0.57223 to 0.57030, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 357ms/step - accuracy: 0.7773 - loss: 0.7960 - val_accuracy: 0.8634 - val_loss: 0.5703 - learning_rate: 0.0010
# Epoch 11/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7870 - loss: 0.7533
# Epoch 11: val_loss did not improve from 0.57030
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 362ms/step - accuracy: 0.7870 - loss: 0.7533 - val_accuracy: 0.8307 - val_loss: 0.5945 - learning_rate: 0.0010
# Epoch 12/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7974 - loss: 0.7240
# Epoch 12: val_loss improved from 0.57030 to 0.56117, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 359ms/step - accuracy: 0.7974 - loss: 0.7241 - val_accuracy: 0.8748 - val_loss: 0.5612 - learning_rate: 0.0010
# Epoch 13/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7809 - loss: 0.7522
# Epoch 13: val_loss improved from 0.56117 to 0.54302, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 356ms/step - accuracy: 0.7809 - loss: 0.7521 - val_accuracy: 0.8663 - val_loss: 0.5430 - learning_rate: 0.0010
# Epoch 14/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.7930 - loss: 0.7204
# Epoch 14: val_loss improved from 0.54302 to 0.53115, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 361ms/step - accuracy: 0.7930 - loss: 0.7205 - val_accuracy: 0.8748 - val_loss: 0.5312 - learning_rate: 0.0010
# Epoch 15/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7973 - loss: 0.7093
# Epoch 15: val_loss improved from 0.53115 to 0.52235, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 353ms/step - accuracy: 0.7973 - loss: 0.7092 - val_accuracy: 0.8663 - val_loss: 0.5223 - learning_rate: 0.0010
# Epoch 16/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7803 - loss: 0.7172
# Epoch 16: val_loss improved from 0.52235 to 0.49548, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 358ms/step - accuracy: 0.7805 - loss: 0.7170 - val_accuracy: 0.8734 - val_loss: 0.4955 - learning_rate: 0.0010
# Epoch 17/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8027 - loss: 0.6689
# Epoch 17: val_loss did not improve from 0.49548
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 354ms/step - accuracy: 0.8027 - loss: 0.6689 - val_accuracy: 0.8435 - val_loss: 0.5474 - learning_rate: 0.0010
# Epoch 18/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8058 - loss: 0.6765
# Epoch 18: val_loss improved from 0.49548 to 0.49099, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 349ms/step - accuracy: 0.8058 - loss: 0.6765 - val_accuracy: 0.8862 - val_loss: 0.4910 - learning_rate: 0.0010
# Epoch 19/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8033 - loss: 0.6777
# Epoch 19: val_loss improved from 0.49099 to 0.47733, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 353ms/step - accuracy: 0.8033 - loss: 0.6776 - val_accuracy: 0.8720 - val_loss: 0.4773 - learning_rate: 0.0010
# Epoch 20/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.7840 - loss: 0.6909
# Epoch 20: val_loss did not improve from 0.47733
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 53s 345ms/step - accuracy: 0.7841 - loss: 0.6908 - val_accuracy: 0.8734 - val_loss: 0.5004 - learning_rate: 0.0010
# Epoch 21/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8043 - loss: 0.6581
# Epoch 21: val_loss improved from 0.47733 to 0.47298, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 353ms/step - accuracy: 0.8043 - loss: 0.6581 - val_accuracy: 0.8706 - val_loss: 0.4730 - learning_rate: 0.0010
# Epoch 22/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8080 - loss: 0.6487
# Epoch 22: val_loss did not improve from 0.47298
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 53s 344ms/step - accuracy: 0.8080 - loss: 0.6487 - val_accuracy: 0.8663 - val_loss: 0.4916 - learning_rate: 0.0010
# Epoch 23/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8137 - loss: 0.6361
# Epoch 23: val_loss did not improve from 0.47298
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 53s 344ms/step - accuracy: 0.8136 - loss: 0.6362 - val_accuracy: 0.8777 - val_loss: 0.4966 - learning_rate: 0.0010
# Epoch 24/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8082 - loss: 0.6466
# Epoch 24: val_loss improved from 0.47298 to 0.45994, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 350ms/step - accuracy: 0.8082 - loss: 0.6467 - val_accuracy: 0.8862 - val_loss: 0.4599 - learning_rate: 0.0010
# Epoch 25/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.7961 - loss: 0.6376
# Epoch 25: val_loss did not improve from 0.45994
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 53s 345ms/step - accuracy: 0.7962 - loss: 0.6376 - val_accuracy: 0.8777 - val_loss: 0.4864 - learning_rate: 0.0010
# Epoch 26/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8025 - loss: 0.6582
# Epoch 26: val_loss did not improve from 0.45994
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 356ms/step - accuracy: 0.8026 - loss: 0.6581 - val_accuracy: 0.8734 - val_loss: 0.4636 - learning_rate: 0.0010
# Epoch 27/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8160 - loss: 0.6321
# Epoch 27: val_loss did not improve from 0.45994
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 351ms/step - accuracy: 0.8160 - loss: 0.6321 - val_accuracy: 0.8890 - val_loss: 0.4609 - learning_rate: 0.0010
# Epoch 28/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8156 - loss: 0.6049
# Epoch 28: val_loss improved from 0.45994 to 0.44762, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 349ms/step - accuracy: 0.8156 - loss: 0.6049 - val_accuracy: 0.8919 - val_loss: 0.4476 - learning_rate: 5.0000e-04
# Epoch 29/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.8178 - loss: 0.6121
# Epoch 29: val_loss improved from 0.44762 to 0.41623, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 53s 344ms/step - accuracy: 0.8178 - loss: 0.6120 - val_accuracy: 0.8976 - val_loss: 0.4162 - learning_rate: 5.0000e-04
# Epoch 30/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8134 - loss: 0.5970
# Epoch 30: val_loss improved from 0.41623 to 0.40397, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 352ms/step - accuracy: 0.8134 - loss: 0.5969 - val_accuracy: 0.9147 - val_loss: 0.4040 - learning_rate: 5.0000e-04
# Epoch 31/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8247 - loss: 0.5777
# Epoch 31: val_loss did not improve from 0.40397
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 354ms/step - accuracy: 0.8247 - loss: 0.5777 - val_accuracy: 0.8848 - val_loss: 0.4350 - learning_rate: 5.0000e-04
# Epoch 32/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8224 - loss: 0.5844
# Epoch 32: val_loss did not improve from 0.40397
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 355ms/step - accuracy: 0.8224 - loss: 0.5844 - val_accuracy: 0.8933 - val_loss: 0.4237 - learning_rate: 5.0000e-04
# Epoch 33/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8268 - loss: 0.5783
# Epoch 33: val_loss improved from 0.40397 to 0.39943, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 57s 368ms/step - accuracy: 0.8268 - loss: 0.5783 - val_accuracy: 0.8933 - val_loss: 0.3994 - learning_rate: 5.0000e-04
# Epoch 34/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8306 - loss: 0.5725
# Epoch 34: val_loss did not improve from 0.39943
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 57s 368ms/step - accuracy: 0.8306 - loss: 0.5725 - val_accuracy: 0.9090 - val_loss: 0.4055 - learning_rate: 5.0000e-04
# Epoch 35/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8402 - loss: 0.5522
# Epoch 35: val_loss did not improve from 0.39943
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8402 - loss: 0.5523 - val_accuracy: 0.8819 - val_loss: 0.4102 - learning_rate: 5.0000e-04
# Epoch 36/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8271 - loss: 0.5701
# Epoch 36: val_loss did not improve from 0.39943
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 364ms/step - accuracy: 0.8271 - loss: 0.5702 - val_accuracy: 0.8848 - val_loss: 0.4019 - learning_rate: 5.0000e-04
# Epoch 37/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8284 - loss: 0.5590
# Epoch 37: val_loss did not improve from 0.39943
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 57s 368ms/step - accuracy: 0.8284 - loss: 0.5590 - val_accuracy: 0.8890 - val_loss: 0.3995 - learning_rate: 2.5000e-04
# Epoch 38/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8297 - loss: 0.5661
# Epoch 38: val_loss improved from 0.39943 to 0.39559, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 364ms/step - accuracy: 0.8297 - loss: 0.5660 - val_accuracy: 0.8947 - val_loss: 0.3956 - learning_rate: 2.5000e-04
# Epoch 39/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8419 - loss: 0.5209
# Epoch 39: val_loss improved from 0.39559 to 0.38934, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 358ms/step - accuracy: 0.8419 - loss: 0.5210 - val_accuracy: 0.8919 - val_loss: 0.3893 - learning_rate: 2.5000e-04
# Epoch 40/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8434 - loss: 0.5293
# Epoch 40: val_loss improved from 0.38934 to 0.36991, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 359ms/step - accuracy: 0.8434 - loss: 0.5293 - val_accuracy: 0.8990 - val_loss: 0.3699 - learning_rate: 2.5000e-04
# Epoch 41/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8428 - loss: 0.5146
# Epoch 41: val_loss did not improve from 0.36991
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 55s 358ms/step - accuracy: 0.8428 - loss: 0.5148 - val_accuracy: 0.8947 - val_loss: 0.4002 - learning_rate: 2.5000e-04
# Epoch 42/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8372 - loss: 0.5398
# Epoch 42: val_loss did not improve from 0.36991
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8372 - loss: 0.5397 - val_accuracy: 0.8976 - val_loss: 0.3813 - learning_rate: 2.5000e-04
# Epoch 43/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8330 - loss: 0.5261
# Epoch 43: val_loss did not improve from 0.36991
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 359ms/step - accuracy: 0.8330 - loss: 0.5262 - val_accuracy: 0.8905 - val_loss: 0.3903 - learning_rate: 2.5000e-04
# Epoch 44/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8282 - loss: 0.5281
# Epoch 44: val_loss did not improve from 0.36991
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 360ms/step - accuracy: 0.8283 - loss: 0.5281 - val_accuracy: 0.9004 - val_loss: 0.3773 - learning_rate: 1.2500e-04
# Epoch 45/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8460 - loss: 0.5175
# Epoch 45: val_loss did not improve from 0.36991
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 364ms/step - accuracy: 0.8460 - loss: 0.5175 - val_accuracy: 0.8962 - val_loss: 0.3739 - learning_rate: 1.2500e-04
# Epoch 46/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8310 - loss: 0.5335
# Epoch 46: val_loss did not improve from 0.36991
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 365ms/step - accuracy: 0.8310 - loss: 0.5335 - val_accuracy: 0.9004 - val_loss: 0.3740 - learning_rate: 1.2500e-04
# Epoch 47/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8373 - loss: 0.5359
# Epoch 47: val_loss improved from 0.36991 to 0.36959, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 352ms/step - accuracy: 0.8374 - loss: 0.5358 - val_accuracy: 0.9047 - val_loss: 0.3696 - learning_rate: 6.2500e-05
# Epoch 48/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8440 - loss: 0.5177
# Epoch 48: val_loss improved from 0.36959 to 0.36400, saving model to vgg19v2.h5
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 56s 360ms/step - accuracy: 0.8440 - loss: 0.5176 - val_accuracy: 0.9104 - val_loss: 0.3640 - learning_rate: 6.2500e-05
# Epoch 49/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8489 - loss: 0.5092
# Epoch 49: val_loss did not improve from 0.36400
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 349ms/step - accuracy: 0.8489 - loss: 0.5092 - val_accuracy: 0.9033 - val_loss: 0.3715 - learning_rate: 6.2500e-05
# Epoch 50/50
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8442 - loss: 0.5050
# Epoch 50: val_loss did not improve from 0.36400
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 54s 351ms/step - accuracy: 0.8442 - loss: 0.5050 - val_accuracy: 0.9075 - val_loss: 0.3646 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 48.

# %% [markdown]
# ## 6. Evaluation & Report

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
epochs = len(history.history['accuracy'])
epoch_range = range(1, epochs + 1)

plt.figure(figsize=(14,5))

# --- Biểu đồ Accuracy ---
plt.subplot(1,2,1)
plt.plot(epoch_range, history.history['accuracy'], label='Train Acc', color='steelblue', linewidth=2)
plt.plot(epoch_range, history.history['val_accuracy'], label='Val Acc', color='darkorange', linewidth=2)
plt.title('Accuracy over Epochs', fontsize=14, fontweight='bold')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.xticks(np.arange(0, epochs+1, max(1, epochs//10)))

# --- Biểu đồ Loss ---
plt.subplot(1,2,2)
plt.plot(epoch_range, history.history['loss'], label='Train Loss', color='steelblue', linewidth=2)
plt.plot(epoch_range, history.history['val_loss'], label='Val Loss', color='darkorange', linewidth=2)
plt.title('Loss over Epochs', fontsize=14, fontweight='bold')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.xticks(np.arange(0, epochs+1, max(1, epochs//10)))

plt.tight_layout()
plt.show()

# %%
loss, acc = model.evaluate(test_generator, verbose=1)
print(f"\n Test Accuracy (from model.evaluate): {acc*100:.2f}%\n")
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 21s 483ms/step - accuracy: 0.8852 - loss: 0.3841
#
#  Test Accuracy (from model.evaluate): 89.18%

# %%
# Dự đoán trên test 
model.load_weights('vgg19v2.h5')
y_prob = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_prob, axis=1)

# lấy true labels 
y_true = Y_test

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred,    average='weighted')
f1  = f1_score(y_true, y_pred,        average='weighted')

print(f"\n Test Accuracy: {acc*100:.2f}%\n")
print(f"\n Test Precision: {precision*100:.2f}%\n")
print(f"\n Test Recall: {recall*100:.2f}%\n")
print(f"\n Test F1-score: {f1*100:.2f}%\n")

print(classification_report(y_true, y_pred, target_names=labels))
cm = confusion_matrix(y_true, y_pred)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step
#
#  Test Accuracy: 89.18%
#
#
#  Test Precision: 89.53%
#
#
#  Test Recall: 89.18%
#
#
#  Test F1-score: 89.18%
#
#               precision    recall  f1-score   support
#
#       glioma       0.92      0.82      0.87       324
#   meningioma       0.80      0.81      0.80       329
#      notumor       0.99      0.95      0.97       400
#    pituitary       0.85      0.97      0.91       352
#
#     accuracy                           0.89      1405
#    macro avg       0.89      0.89      0.89      1405
# weighted avg       0.90      0.89      0.89      1405

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.show()

# %%
NUM_CLASSES = len(labels)
samples_per_class = 4  

X_test_array = X_test  
y_true_array = y_true
y_pred_array = y_pred

# Tạo dictionary để lưu ảnh theo lớp
imgs_by_class = {cls_idx: [] for cls_idx in range(NUM_CLASSES)}

for idx, (img, true_label, pred_label) in enumerate(zip(X_test_array, y_true_array, y_pred_array)):
    if len(imgs_by_class[true_label]) < samples_per_class:
        imgs_by_class[true_label].append((img, true_label, pred_label))
    # nếu tất cả lớp đều đủ ảnh thì dừng
    if all(len(v) >= samples_per_class for v in imgs_by_class.values()):
        break

# Vẽ hình ảnh
plt.figure(figsize=(samples_per_class * 3, NUM_CLASSES * 3))
plot_idx = 1
for cls_idx in range(NUM_CLASSES):
    for (img, t, p) in imgs_by_class[cls_idx]:
        plt.subplot(NUM_CLASSES, samples_per_class, plot_idx)
        plt.imshow(img[..., 0] if img.shape[-1]==1 else img) 
        title_color = 'green' if t == p else 'red'
        plt.title(f"True: {labels[t]}\nPred: {labels[p]}", color=title_color)
        plt.axis('off')
        plot_idx += 1

plt.tight_layout()
plt.show()
